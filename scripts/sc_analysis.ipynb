# %%
import sys
sys.path.append('../')
from src.sclibs import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = prep_data(DATA_DIR='../../TP53loss_WGD_data/')

# %%
necklace_plots(**data)
# Out:
# ERL-Resis_FL : 231
# ERL-Resis_WT : 176
# never.tx_FL : 457
# never.tx_WT : 341

# %%
cell_ploidy(**data)
# Out:
# E Treated v.s. EP Untreated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.385e-05 U_stat=3.000e+00
# E Untreated v.s. EP Untreated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.467e-03 U_stat=9.000e+01
# E Treated v.s. EP Treated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.160e-03 U_stat=3.000e+00

# %%
shannon_eveness(**data)
# Out:
# E Treated v.s. EP Untreated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.174e-02 U_stat=1.800e+01
# E Untreated v.s. EP Untreated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.081e-02 U_stat=1.010e+02
# E Treated v.s. EP Treated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.902e-03 U_stat=2.000e+00
# E Untreated v.s. EP Treated: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.693e-03 U_stat=2.450e+01

# %%
cn_heatmap_Euntreated(**data)

# %%
cn_heatmap_EPuntreated(**data)

# %%
cn_heatmap_Etreated(**data)

# %%
cn_heatmap_EPtreated(**data)
